# %% [markdown]
# # DFAnalyzer Simple Example
#
# This notebook will guide you to load a trace file generated by DFTracer and analyze the trace events using Dask.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## System imports for the notebook

# %%
import os
from pathlib import Path
import sys

# %% [markdown]
# ## We add the analysis code to path so that we can run this in dev mode.

# %%
app_root = str(Path(os.getcwd()).parent.parent)
sys.path.insert(0, app_root)
app_root
# Out:
# '/usr/WS2/sinurat1/dftracer'

# %% [markdown]
# ## Imports for the notebook
#
# This may take some time as it initializes Dask.

# %%
from dftracer.analyzer import init_with_hydra

percentile = 0.9
time_granularity = 5  # 5 seconds
trace_path = f"{app_root}/examples/dfanalyzer"
view_types = ["time_range", "proc_name"]

dfa = init_with_hydra(
    hydra_overrides=[
        f"trace_path={trace_path}",
    ]
)

# %% [markdown]
# ## Dask Client
#
# This is needed for SSH forwarding in case we need to see the Dask Dashboard

# %%
dfa.client
# Out:
# <Client: 'tcp://127.0.0.1:33587' processes=12 threads=96>

# %% [markdown]
# ## Analyze the events

# %%
res = dfa.analyze_trace()

# %% [markdown]
# ## Show the analysis

# %%
dfa.output.handle_result(res)
# Out:
#                                                 Time Period Summary
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Metric                                                       ┃ Unit                  ┃                    Value ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Job Time                                                     │ seconds               │                  179.811 │
# │ Total Count                                                  │ count                 │                   74,360 │
# │ Total Files                                                  │ count                 │                    1,027 │
# │ Total Nodes                                                  │ count                 │                        1 │
# │ Total Processes                                              │ count                 │                        1 │
# │ POSIX Count                                                  │ count                 │                   71,302 │
# │ POSIX Size                                                   │ MB                    │                17454.707 │
# │ POSIX Bandwidth                                              │ MB/s                  │                 2617.717 │
# │ POSIX Avg Transfer Size                                      │ MB                    │                    0.245 │
# └──────────────────────────────────────────────────────────────┴───────────────────────┴──────────────────────────┘
#                                                   Layer Breakdown
# ┏━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer      ┃        Time (s) ┃          Ops ┃          Ops/sec ┃        Size (MB) ┃            Bandwidth (MB/s) ┃
# ┡━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ POSIX      │           6.668 │       71,302 │        10693.301 │        17454.707 │                    2617.717 │
# └────────────┴─────────────────┴──────────────┴──────────────────┴──────────────────┴─────────────────────────────┘
